# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Downloading mnist: 9.92MB [00:02, 4.89MB/s]
# Extracting mnist: 100%|██████████| 60.0K/60.0K [00:10<00:00, 5.84KFile/s]
# Downloading celeba: 1.44GB [00:17, 81.6MB/s]
# Extracting celeba...

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    inputs_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real')
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    l_rate = tf.placeholder(tf.float32, None, name="l_rate")

    return inputs_real, inputs_z, l_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 32x32x3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        relu1 = tf.maximum(0.2 * x1, x1)
        # 16x16x32
        
        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(0.2 * bn2, bn2)
        # 8x8x128
        
        x3 = tf.layers.conv2d(relu2, 256, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(0.2 * bn3, bn3)
        # 4x4x256

        # Flatten it
        flat = tf.reshape(relu3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
    return out, logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    
    alpha = 0.2
    
    with tf.variable_scope('generator', reuse=not(is_train)):
#         x1 = tf.layers.dense(z, 7*7*256)
#         x1 = tf.reshape(x1, (-1, 7, 7, 256))

#         x1 = tf.layers.batch_normalization(x1, training=is_train)
#         x1 = tf.maximum(0.2*x1, x1)

#         # Now for the transpose convolutions..

#         x2 = tf.layers.conv2d_transpose(x1, 128, 1, strides=1, padding='SAME')
#         x2 = tf.layers.batch_normalization(x2, training=is_train)
#         x2 = tf.maximum(0.2*x2, x2)

#         x3 = tf.layers.conv2d_transpose(x2, 64, 3, strides=2, padding='SAME')
#         x3 = tf.layers.batch_normalization(x3, training=is_train)
#         x3 = tf.maximum(0.2*x3, x3)

#         logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 3, strides=2, padding='SAME')
#         out = tf.tanh(logits)

        x1 = tf.layers.dense(z, 2*2*512)

        x1 = tf.reshape(x1, (-1, 2, 2, 512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides=2, padding='valid')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides=2, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)

        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides=2, padding='same')
        
        out = tf.tanh(logits)

        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    input_real, input_z, _ = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)

    d_loss, g_loss = model_loss(input_real, input_z, data_shape[3])
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
        
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for e in range(epochs):
            steps = 0
            for batch_images in get_batches(batch_size):
                steps += 1

                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_real: batch_images, input_z: batch_z})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z})

                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(e+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))

                if steps % 100 == 0:
                    show_generator_output(sess, 1, input_z, data_shape[3], data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.0001

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 1.1032... Generator Loss: 1.0387
# Epoch 1/2... Discriminator Loss: 2.8813... Generator Loss: 2.9926
# Epoch 1/2... Discriminator Loss: 2.2295... Generator Loss: 3.0717
# Epoch 1/2... Discriminator Loss: 1.3337... Generator Loss: 3.8217
# Epoch 1/2... Discriminator Loss: 1.4376... Generator Loss: 3.6201
# Epoch 1/2... Discriminator Loss: 1.3281... Generator Loss: 1.7354
# Epoch 1/2... Discriminator Loss: 1.3627... Generator Loss: 1.6405
# Epoch 1/2... Discriminator Loss: 1.2467... Generator Loss: 1.4636
# Epoch 1/2... Discriminator Loss: 1.4384... Generator Loss: 1.8040
# Epoch 1/2... Discriminator Loss: 1.3167... Generator Loss: 1.8316
# Epoch 1/2... Discriminator Loss: 1.2744... Generator Loss: 1.9697
# Epoch 1/2... Discriminator Loss: 1.2042... Generator Loss: 1.7711
# Epoch 1/2... Discriminator Loss: 1.1905... Generator Loss: 1.9673
# Epoch 1/2... Discriminator Loss: 1.1198... Generator Loss: 2.0642
# Epoch 1/2... Discriminator Loss: 1.0635... Generator Loss: 2.0804
# Epoch 1/2... Discriminator Loss: 1.0370... Generator Loss: 2.2212
# Epoch 1/2... Discriminator Loss: 0.9975... Generator Loss: 2.3441
# Epoch 1/2... Discriminator Loss: 0.9083... Generator Loss: 2.3419
# Epoch 1/2... Discriminator Loss: 0.9811... Generator Loss: 2.5911
# Epoch 1/2... Discriminator Loss: 1.0037... Generator Loss: 2.9140
# Epoch 1/2... Discriminator Loss: 0.5454... Generator Loss: 2.6029
# Epoch 1/2... Discriminator Loss: 1.0255... Generator Loss: 3.0196
# Epoch 1/2... Discriminator Loss: 1.0285... Generator Loss: 3.2945
# Epoch 1/2... Discriminator Loss: 0.6743... Generator Loss: 3.3198
# Epoch 1/2... Discriminator Loss: 0.7158... Generator Loss: 3.0115
# Epoch 1/2... Discriminator Loss: 0.6989... Generator Loss: 3.1904
# Epoch 1/2... Discriminator Loss: 0.7278... Generator Loss: 3.5237
# Epoch 1/2... Discriminator Loss: 0.5734... Generator Loss: 3.3010
# Epoch 1/2... Discriminator Loss: 1.1201... Generator Loss: 4.1880
# Epoch 1/2... Discriminator Loss: 0.6813... Generator Loss: 3.5819
# Epoch 1/2... Discriminator Loss: 0.7294... Generator Loss: 3.4182
# Epoch 1/2... Discriminator Loss: 0.2692... Generator Loss: 3.0520
# Epoch 1/2... Discriminator Loss: 1.1775... Generator Loss: 2.8320
# Epoch 1/2... Discriminator Loss: 0.3023... Generator Loss: 3.2751
# Epoch 1/2... Discriminator Loss: 0.3949... Generator Loss: 3.4476
# Epoch 1/2... Discriminator Loss: 1.2591... Generator Loss: 2.5878
# Epoch 1/2... Discriminator Loss: 0.2450... Generator Loss: 2.6421
# Epoch 1/2... Discriminator Loss: 0.5307... Generator Loss: 3.9031
# Epoch 1/2... Discriminator Loss: 0.9294... Generator Loss: 2.8178
# Epoch 1/2... Discriminator Loss: 0.4137... Generator Loss: 2.9466
# Epoch 1/2... Discriminator Loss: 0.2783... Generator Loss: 2.8374
# Epoch 1/2... Discriminator Loss: 0.6212... Generator Loss: 3.6341
# Epoch 1/2... Discriminator Loss: 0.3114... Generator Loss: 3.0319
# Epoch 1/2... Discriminator Loss: 0.3321... Generator Loss: 3.6560
# Epoch 1/2... Discriminator Loss: 0.3315... Generator Loss: 3.4274
# Epoch 1/2... Discriminator Loss: 0.4863... Generator Loss: 3.8053
# Epoch 2/2... Discriminator Loss: 0.4077... Generator Loss: 1.9151
# Epoch 2/2... Discriminator Loss: 0.3014... Generator Loss: 1.6951
# Epoch 2/2... Discriminator Loss: 0.2256... Generator Loss: 1.9958
# Epoch 2/2... Discriminator Loss: 0.3477... Generator Loss: 1.4474
# Epoch 2/2... Discriminator Loss: 0.3540... Generator Loss: 1.4565
# Epoch 2/2... Discriminator Loss: 0.2677... Generator Loss: 1.6829
# Epoch 2/2... Discriminator Loss: 0.3943... Generator Loss: 1.2977
# Epoch 2/2... Discriminator Loss: 2.2279... Generator Loss: 0.1424
# Epoch 2/2... Discriminator Loss: 0.6001... Generator Loss: 1.9424
# Epoch 2/2... Discriminator Loss: 0.3814... Generator Loss: 1.5017
# Epoch 2/2... Discriminator Loss: 0.2646... Generator Loss: 1.8862
# Epoch 2/2... Discriminator Loss: 0.2429... Generator Loss: 1.9698
# Epoch 2/2... Discriminator Loss: 0.2197... Generator Loss: 1.9454
# Epoch 2/2... Discriminator Loss: 0.2081... Generator Loss: 2.0024
# Epoch 2/2... Discriminator Loss: 0.2496... Generator Loss: 1.7751
# Epoch 2/2... Discriminator Loss: 0.1429... Generator Loss: 2.7791
# Epoch 2/2... Discriminator Loss: 0.4097... Generator Loss: 1.2124
# Epoch 2/2... Discriminator Loss: 0.2173... Generator Loss: 1.9039
# Epoch 2/2... Discriminator Loss: 2.9441... Generator Loss: 0.0734
# Epoch 2/2... Discriminator Loss: 0.9063... Generator Loss: 0.6375
# Epoch 2/2... Discriminator Loss: 0.4662... Generator Loss: 1.2647
# Epoch 2/2... Discriminator Loss: 0.3024... Generator Loss: 1.7446
# Epoch 2/2... Discriminator Loss: 0.2564... Generator Loss: 1.8391
# Epoch 2/2... Discriminator Loss: 0.1795... Generator Loss: 2.2854
# Epoch 2/2... Discriminator Loss: 0.1291... Generator Loss: 2.8891
# Epoch 2/2... Discriminator Loss: 0.1016... Generator Loss: 4.1748
# Epoch 2/2... Discriminator Loss: 0.1155... Generator Loss: 2.8387
# Epoch 2/2... Discriminator Loss: 1.5614... Generator Loss: 2.4551
# Epoch 2/2... Discriminator Loss: 1.1541... Generator Loss: 2.2666
# Epoch 2/2... Discriminator Loss: 0.4357... Generator Loss: 2.2533
# Epoch 2/2... Discriminator Loss: 0.2877... Generator Loss: 1.8124
# Epoch 2/2... Discriminator Loss: 0.1655... Generator Loss: 2.4755
# Epoch 2/2... Discriminator Loss: 0.1704... Generator Loss: 2.4386
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-d2c63dd94215> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
# ---> 14           mnist_dataset.shape, mnist_dataset.image_mode)
#
# <ipython-input-96-12967719c4fd> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      28
#      29                 # Run optimizers
# ---> 30                 _ = sess.run(d_opt, feed_dict={input_real: batch_images, input_z: batch_z})
#      31                 _ = sess.run(g_opt, feed_dict={input_z: batch_z})
#      32
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.001


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.1905... Generator Loss: 2.2867
# Epoch 1/1... Discriminator Loss: 0.0891... Generator Loss: 3.3604
# Epoch 1/1... Discriminator Loss: 0.4330... Generator Loss: 1.1947
# Epoch 1/1... Discriminator Loss: 0.4573... Generator Loss: 1.7612
# Epoch 1/1... Discriminator Loss: 1.1254... Generator Loss: 0.4699
# Epoch 1/1... Discriminator Loss: 0.4848... Generator Loss: 1.4329
# Epoch 1/1... Discriminator Loss: 0.8988... Generator Loss: 0.6176
# Epoch 1/1... Discriminator Loss: 1.4485... Generator Loss: 0.3731
# Epoch 1/1... Discriminator Loss: 0.7383... Generator Loss: 1.3989
# Epoch 1/1... Discriminator Loss: 1.8631... Generator Loss: 5.3097
# Epoch 1/1... Discriminator Loss: 0.3661... Generator Loss: 1.9772
# Epoch 1/1... Discriminator Loss: 1.7978... Generator Loss: 0.2052
# Epoch 1/1... Discriminator Loss: 0.2968... Generator Loss: 1.9585
# Epoch 1/1... Discriminator Loss: 0.4387... Generator Loss: 1.2358
# Epoch 1/1... Discriminator Loss: 0.8836... Generator Loss: 0.6290
# Epoch 1/1... Discriminator Loss: 0.3590... Generator Loss: 2.6564
# Epoch 1/1... Discriminator Loss: 1.4094... Generator Loss: 6.0032
# Epoch 1/1... Discriminator Loss: 0.2798... Generator Loss: 1.8798
# Epoch 1/1... Discriminator Loss: 3.2461... Generator Loss: 6.8125
# Epoch 1/1... Discriminator Loss: 0.5307... Generator Loss: 2.6749
# Epoch 1/1... Discriminator Loss: 0.6820... Generator Loss: 2.6732
# Epoch 1/1... Discriminator Loss: 1.8689... Generator Loss: 3.5332
# Epoch 1/1... Discriminator Loss: 0.7009... Generator Loss: 2.3445
# Epoch 1/1... Discriminator Loss: 1.5420... Generator Loss: 1.9775
# Epoch 1/1... Discriminator Loss: 1.0743... Generator Loss: 1.7990
# Epoch 1/1... Discriminator Loss: 0.5137... Generator Loss: 2.2648
# Epoch 1/1... Discriminator Loss: 1.7646... Generator Loss: 2.0226
# Epoch 1/1... Discriminator Loss: 0.4974... Generator Loss: 2.9981
# Epoch 1/1... Discriminator Loss: 1.3886... Generator Loss: 1.9410
# Epoch 1/1... Discriminator Loss: 0.3988... Generator Loss: 3.0173
# Epoch 1/1... Discriminator Loss: 1.3509... Generator Loss: 3.5650
# Epoch 1/1... Discriminator Loss: 0.8438... Generator Loss: 1.6239
# Epoch 1/1... Discriminator Loss: 0.4169... Generator Loss: 2.8201
# Epoch 1/1... Discriminator Loss: 0.8875... Generator Loss: 2.4536
# Epoch 1/1... Discriminator Loss: 1.1449... Generator Loss: 3.3818
# Epoch 1/1... Discriminator Loss: 0.4522... Generator Loss: 2.1327
# Epoch 1/1... Discriminator Loss: 0.6807... Generator Loss: 0.8445
# Epoch 1/1... Discriminator Loss: 1.4117... Generator Loss: 0.3382
# Epoch 1/1... Discriminator Loss: 0.8187... Generator Loss: 0.7320
# Epoch 1/1... Discriminator Loss: 0.7680... Generator Loss: 0.7680
# Epoch 1/1... Discriminator Loss: 1.0428... Generator Loss: 0.5530
# Epoch 1/1... Discriminator Loss: 0.8665... Generator Loss: 0.7546
# Epoch 1/1... Discriminator Loss: 1.3568... Generator Loss: 0.3626
# Epoch 1/1... Discriminator Loss: 0.4492... Generator Loss: 1.2644
# Epoch 1/1... Discriminator Loss: 0.7776... Generator Loss: 0.7283
# Epoch 1/1... Discriminator Loss: 0.8925... Generator Loss: 0.6673
# Epoch 1/1... Discriminator Loss: 1.0355... Generator Loss: 0.5386
# Epoch 1/1... Discriminator Loss: 0.8029... Generator Loss: 0.7228
# Epoch 1/1... Discriminator Loss: 0.2884... Generator Loss: 1.9914
# Epoch 1/1... Discriminator Loss: 0.7570... Generator Loss: 6.6436
# Epoch 1/1... Discriminator Loss: 1.5214... Generator Loss: 0.3087
# Epoch 1/1... Discriminator Loss: 0.6719... Generator Loss: 0.8889
# Epoch 1/1... Discriminator Loss: 0.9283... Generator Loss: 0.6032
# Epoch 1/1... Discriminator Loss: 0.5702... Generator Loss: 1.0080
# Epoch 1/1... Discriminator Loss: 1.0179... Generator Loss: 0.5395
# Epoch 1/1... Discriminator Loss: 0.8729... Generator Loss: 0.6658
# Epoch 1/1... Discriminator Loss: 0.4635... Generator Loss: 1.2421
# Epoch 1/1... Discriminator Loss: 0.1930... Generator Loss: 2.1913
# Epoch 1/1... Discriminator Loss: 0.0848... Generator Loss: 4.2518
# Epoch 1/1... Discriminator Loss: 1.6154... Generator Loss: 6.5485
# Epoch 1/1... Discriminator Loss: 0.2780... Generator Loss: 1.7589
# Epoch 1/1... Discriminator Loss: 1.0138... Generator Loss: 0.5485
# Epoch 1/1... Discriminator Loss: 0.2004... Generator Loss: 3.3852
# Epoch 1/1... Discriminator Loss: 0.2601... Generator Loss: 1.7930
# Epoch 1/1... Discriminator Loss: 0.9629... Generator Loss: 0.5608
# Epoch 1/1... Discriminator Loss: 0.1328... Generator Loss: 2.5712
# Epoch 1/1... Discriminator Loss: 0.7393... Generator Loss: 0.7977
# Epoch 1/1... Discriminator Loss: 0.0827... Generator Loss: 6.1632
# Epoch 1/1... Discriminator Loss: 1.3687... Generator Loss: 0.3388
# Epoch 1/1... Discriminator Loss: 0.1271... Generator Loss: 2.7189
# Epoch 1/1... Discriminator Loss: 0.3658... Generator Loss: 1.4095
# Epoch 1/1... Discriminator Loss: 0.1116... Generator Loss: 3.4146
# Epoch 1/1... Discriminator Loss: 0.1252... Generator Loss: 5.9136
# Epoch 1/1... Discriminator Loss: 0.0502... Generator Loss: 5.3416
# Epoch 1/1... Discriminator Loss: 0.0551... Generator Loss: 5.4261
# Epoch 1/1... Discriminator Loss: 0.1666... Generator Loss: 6.7133
# Epoch 1/1... Discriminator Loss: 1.6073... Generator Loss: 4.6279
# Epoch 1/1... Discriminator Loss: 1.1773... Generator Loss: 1.2651
# Epoch 1/1... Discriminator Loss: 0.5359... Generator Loss: 1.0707
# Epoch 1/1... Discriminator Loss: 0.3549... Generator Loss: 1.4604
# Epoch 1/1... Discriminator Loss: 0.1149... Generator Loss: 3.0868
# Epoch 1/1... Discriminator Loss: 0.5582... Generator Loss: 1.0035
# Epoch 1/1... Discriminator Loss: 0.1867... Generator Loss: 2.1133
# Epoch 1/1... Discriminator Loss: 0.6279... Generator Loss: 0.8649
# Epoch 1/1... Discriminator Loss: 0.1150... Generator Loss: 2.5615
# Epoch 1/1... Discriminator Loss: 0.3679... Generator Loss: 1.4404
# Epoch 1/1... Discriminator Loss: 0.9521... Generator Loss: 0.5965
# Epoch 1/1... Discriminator Loss: 0.2678... Generator Loss: 5.3973
# Epoch 1/1... Discriminator Loss: 1.3316... Generator Loss: 1.7629
# Epoch 1/1... Discriminator Loss: 0.4319... Generator Loss: 6.7587
# Epoch 1/1... Discriminator Loss: 0.1581... Generator Loss: 6.9119
# Epoch 1/1... Discriminator Loss: 0.2304... Generator Loss: 6.3765
# Epoch 1/1... Discriminator Loss: 0.1053... Generator Loss: 6.4406
# Epoch 1/1... Discriminator Loss: 0.1398... Generator Loss: 7.8472
# Epoch 1/1... Discriminator Loss: 1.0408... Generator Loss: 0.5000
# Epoch 1/1... Discriminator Loss: 2.4028... Generator Loss: 2.5979
# Epoch 1/1... Discriminator Loss: 0.5576... Generator Loss: 4.9067
# Epoch 1/1... Discriminator Loss: 0.2109... Generator Loss: 2.0540
# Epoch 1/1... Discriminator Loss: 0.1515... Generator Loss: 2.7878
# Epoch 1/1... Discriminator Loss: 0.4894... Generator Loss: 1.1338
# Epoch 1/1... Discriminator Loss: 0.6938... Generator Loss: 0.8275
# Epoch 1/1... Discriminator Loss: 0.9504... Generator Loss: 0.5720
# Epoch 1/1... Discriminator Loss: 1.8186... Generator Loss: 0.2367
# Epoch 1/1... Discriminator Loss: 0.2675... Generator Loss: 1.7639
# Epoch 1/1... Discriminator Loss: 0.2033... Generator Loss: 2.1924
# Epoch 1/1... Discriminator Loss: 0.1593... Generator Loss: 2.3817
# Epoch 1/1... Discriminator Loss: 0.2627... Generator Loss: 1.8195
# Epoch 1/1... Discriminator Loss: 0.3338... Generator Loss: 1.4784
# Epoch 1/1... Discriminator Loss: 0.7336... Generator Loss: 0.7799
# Epoch 1/1... Discriminator Loss: 0.0205... Generator Loss: 6.0822
# Epoch 1/1... Discriminator Loss: 0.8153... Generator Loss: 7.1126
# Epoch 1/1... Discriminator Loss: 0.5781... Generator Loss: 5.6810
# Epoch 1/1... Discriminator Loss: 1.0056... Generator Loss: 0.5477
# Epoch 1/1... Discriminator Loss: 0.2817... Generator Loss: 1.7391
# Epoch 1/1... Discriminator Loss: 0.3773... Generator Loss: 1.3893
# Epoch 1/1... Discriminator Loss: 0.5383... Generator Loss: 1.0457
# Epoch 1/1... Discriminator Loss: 1.4355... Generator Loss: 7.0537
# Epoch 1/1... Discriminator Loss: 0.0420... Generator Loss: 7.1619
# Epoch 1/1... Discriminator Loss: 1.1995... Generator Loss: 0.4202
# Epoch 1/1... Discriminator Loss: 1.8963... Generator Loss: 0.2483
# Epoch 1/1... Discriminator Loss: 0.2457... Generator Loss: 7.2578
# Epoch 1/1... Discriminator Loss: 0.0967... Generator Loss: 9.4219
# Epoch 1/1... Discriminator Loss: 0.4804... Generator Loss: 5.9556
# Epoch 1/1... Discriminator Loss: 0.0352... Generator Loss: 4.8834
# Epoch 1/1... Discriminator Loss: 0.0622... Generator Loss: 5.9725
# Epoch 1/1... Discriminator Loss: 0.2733... Generator Loss: 1.6551
# Epoch 1/1... Discriminator Loss: 0.0914... Generator Loss: 2.9672
# Epoch 1/1... Discriminator Loss: 0.6001... Generator Loss: 0.9082
# Epoch 1/1... Discriminator Loss: 0.3387... Generator Loss: 1.4193
# Epoch 1/1... Discriminator Loss: 0.0344... Generator Loss: 8.6943
# Epoch 1/1... Discriminator Loss: 0.0502... Generator Loss: 8.4601
# Epoch 1/1... Discriminator Loss: 0.0727... Generator Loss: 3.2010
# Epoch 1/1... Discriminator Loss: 0.0428... Generator Loss: 3.9843
# Epoch 1/1... Discriminator Loss: 0.0412... Generator Loss: 4.0274
# Epoch 1/1... Discriminator Loss: 1.2725... Generator Loss: 1.0433
# Epoch 1/1... Discriminator Loss: 1.3139... Generator Loss: 0.4081
# Epoch 1/1... Discriminator Loss: 0.4279... Generator Loss: 1.4936
# Epoch 1/1... Discriminator Loss: 0.5328... Generator Loss: 1.0287
# Epoch 1/1... Discriminator Loss: 1.0063... Generator Loss: 0.5660
# Epoch 1/1... Discriminator Loss: 0.5750... Generator Loss: 1.0492
# Epoch 1/1... Discriminator Loss: 1.3055... Generator Loss: 0.3621
# Epoch 1/1... Discriminator Loss: 0.1188... Generator Loss: 2.8624
# Epoch 1/1... Discriminator Loss: 0.3636... Generator Loss: 1.4023
# Epoch 1/1... Discriminator Loss: 0.0692... Generator Loss: 3.5330
# Epoch 1/1... Discriminator Loss: 0.0940... Generator Loss: 2.9949
# Epoch 1/1... Discriminator Loss: 0.3835... Generator Loss: 1.2940
# Epoch 1/1... Discriminator Loss: 0.7291... Generator Loss: 0.7632
# Epoch 1/1... Discriminator Loss: 1.5179... Generator Loss: 0.3515
# Epoch 1/1... Discriminator Loss: 0.1314... Generator Loss: 2.7027
# Epoch 1/1... Discriminator Loss: 0.3299... Generator Loss: 1.4648
# Epoch 1/1... Discriminator Loss: 0.4091... Generator Loss: 1.2521
# Epoch 1/1... Discriminator Loss: 0.0427... Generator Loss: 9.2705
# Epoch 1/1... Discriminator Loss: 0.0271... Generator Loss: 5.0066
# Epoch 1/1... Discriminator Loss: 0.2319... Generator Loss: 1.7896
# Epoch 1/1... Discriminator Loss: 0.0992... Generator Loss: 2.6310
# Epoch 1/1... Discriminator Loss: 0.0456... Generator Loss: 4.0655
# Epoch 1/1... Discriminator Loss: 0.0658... Generator Loss: 3.2490
# Epoch 1/1... Discriminator Loss: 1.6464... Generator Loss: 0.3148

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
